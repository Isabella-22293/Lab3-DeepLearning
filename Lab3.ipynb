# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import itertools
import pandas as pd

# %%
#Carga del Dataset MNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

def get_dataloader(batch_size=64):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 7.10MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 446kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.50MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.80MB/s]

# %%
# Definición de la clase MLP
class MLP(nn.Module):
    def __init__(self, hidden_layers=[128, 64], activation='relu'):
        super(MLP, self).__init__()
        
        self.activation = activation
        layers = []
        
        input_size = 28*28
        for hidden_size in hidden_layers:
            layers.append(nn.Linear(input_size, hidden_size))
            input_size = hidden_size
        layers.append(nn.Linear(input_size, 10))
        
        self.layers = nn.ModuleList(layers)

    def forward(self, x):
        x = x.view(-1, 28*28)
        for i, layer in enumerate(self.layers):
            x = layer(x)
            if i < len(self.layers) - 1:
                if self.activation == 'relu':
                    x = F.relu(x)
                elif self.activation == 'tanh':
                    x = torch.tanh(x)
                elif self.activation == 'sigmoid':
                    x = torch.sigmoid(x)
        return x

# %%
# Entrenamiento y Evaluación
def train_model(model, train_loader, optimizer, criterion, epochs=5):
    model.train()
    for epoch in range(epochs):
        total_loss = 0
        for images, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {total_loss/len(train_loader):.4f}")

def evaluate_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    return accuracy

# %%
# Grid Search de Hiperparámetros
hidden_layers_options = [[128, 64], [256, 128, 64], [64]]
activation_options = ['relu', 'tanh', 'sigmoid']
learning_rate_options = [0.001, 0.01]
batch_size_options = [32, 64]
epochs_options = [5, 10]

# Generar todas las combinaciones
grid = list(itertools.product(hidden_layers_options, activation_options, learning_rate_options, batch_size_options, epochs_options))

print(f"Total de combinaciones: {len(grid)}")

grid_results = []

for idx, (hidden_layers, activation, lr, batch_size, epochs) in enumerate(grid):
    print(f"\n=== Probando Configuración {idx+1}/{len(grid)} ===")
    print(f"Capas: {hidden_layers} | Activación: {activation} | LR: {lr} | Batch: {batch_size} | Epochs: {epochs}")
    
    train_loader, test_loader = get_dataloader(batch_size=batch_size)
    model = MLP(hidden_layers=hidden_layers, activation=activation)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    train_model(model, train_loader, optimizer, criterion, epochs=epochs)
    acc = evaluate_model(model, test_loader)
    print(f"Accuracy: {acc:.2f}%")
    
    grid_results.append({
        "Capas Ocultas": hidden_layers,
        "Activación": activation,
        "Learning Rate": lr,
        "Batch Size": batch_size,
        "Epochs": epochs,
        "Accuracy": acc
    })
# Out:
# Total de combinaciones: 72
#
# === Probando Configuración 1/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3566
# Epoch [2/5], Loss: 0.1703
# Epoch [3/5], Loss: 0.1295
# Epoch [4/5], Loss: 0.1106
# Epoch [5/5], Loss: 0.0963
# Accuracy: 96.13%
#
# === Probando Configuración 2/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3429
# Epoch [2/10], Loss: 0.1629
# Epoch [3/10], Loss: 0.1231
# Epoch [4/10], Loss: 0.1027
# Epoch [5/10], Loss: 0.0883
# Epoch [6/10], Loss: 0.0788
# Epoch [7/10], Loss: 0.0700
# Epoch [8/10], Loss: 0.0632
# Epoch [9/10], Loss: 0.0579
# Epoch [10/10], Loss: 0.0534
# Accuracy: 97.10%
#
# === Probando Configuración 3/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3927
# Epoch [2/5], Loss: 0.1841
# Epoch [3/5], Loss: 0.1329
# Epoch [4/5], Loss: 0.1092
# Epoch [5/5], Loss: 0.0954
# Accuracy: 97.10%
#
# === Probando Configuración 4/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3968
# Epoch [2/10], Loss: 0.1900
# Epoch [3/10], Loss: 0.1382
# Epoch [4/10], Loss: 0.1106
# Epoch [5/10], Loss: 0.0936
# Epoch [6/10], Loss: 0.0840
# Epoch [7/10], Loss: 0.0732
# Epoch [8/10], Loss: 0.0663
# Epoch [9/10], Loss: 0.0603
# Epoch [10/10], Loss: 0.0546
# Accuracy: 97.07%
#
# === Probando Configuración 5/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.4165
# Epoch [2/5], Loss: 0.3088
# Epoch [3/5], Loss: 0.2854
# Epoch [4/5], Loss: 0.2715
# Epoch [5/5], Loss: 0.2583
# Accuracy: 92.35%
#
# === Probando Configuración 6/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.4227
# Epoch [2/10], Loss: 0.3210
# Epoch [3/10], Loss: 0.2982
# Epoch [4/10], Loss: 0.2897
# Epoch [5/10], Loss: 0.2805
# Epoch [6/10], Loss: 0.2700
# Epoch [7/10], Loss: 0.2623
# Epoch [8/10], Loss: 0.2577
# Epoch [9/10], Loss: 0.2604
# Epoch [10/10], Loss: 0.2624
# Accuracy: 93.60%
#
# === Probando Configuración 7/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3703
# Epoch [2/5], Loss: 0.2470
# Epoch [3/5], Loss: 0.2260
# Epoch [4/5], Loss: 0.2102
# Epoch [5/5], Loss: 0.1988
# Accuracy: 94.48%
#
# === Probando Configuración 8/72 ===
# Capas: [128, 64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3861
# Epoch [2/10], Loss: 0.2495
# Epoch [3/10], Loss: 0.2208
# Epoch [4/10], Loss: 0.2094
# Epoch [5/10], Loss: 0.2049
# Epoch [6/10], Loss: 0.1951
# Epoch [7/10], Loss: 0.1956
# Epoch [8/10], Loss: 0.1881
# Epoch [9/10], Loss: 0.1857
# Epoch [10/10], Loss: 0.1816
# Accuracy: 95.18%
#
# === Probando Configuración 9/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3229
# Epoch [2/5], Loss: 0.1844
# Epoch [3/5], Loss: 0.1581
# Epoch [4/5], Loss: 0.1448
# Epoch [5/5], Loss: 0.1354
# Accuracy: 94.93%
#
# === Probando Configuración 10/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3289
# Epoch [2/10], Loss: 0.1843
# Epoch [3/10], Loss: 0.1543
# Epoch [4/10], Loss: 0.1395
# Epoch [5/10], Loss: 0.1284
# Epoch [6/10], Loss: 0.1227
# Epoch [7/10], Loss: 0.1198
# Epoch [8/10], Loss: 0.1136
# Epoch [9/10], Loss: 0.1093
# Epoch [10/10], Loss: 0.1045
# Accuracy: 96.10%
#
# === Probando Configuración 11/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3443
# Epoch [2/5], Loss: 0.1566
# Epoch [3/5], Loss: 0.1231
# Epoch [4/5], Loss: 0.1080
# Epoch [5/5], Loss: 0.0971
# Accuracy: 95.11%
#
# === Probando Configuración 12/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3473
# Epoch [2/10], Loss: 0.1568
# Epoch [3/10], Loss: 0.1271
# Epoch [4/10], Loss: 0.1122
# Epoch [5/10], Loss: 0.1014
# Epoch [6/10], Loss: 0.0937
# Epoch [7/10], Loss: 0.0870
# Epoch [8/10], Loss: 0.0830
# Epoch [9/10], Loss: 0.0813
# Epoch [10/10], Loss: 0.0786
# Accuracy: 96.69%
#
# === Probando Configuración 13/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 1.9812
# Epoch [2/5], Loss: 1.9636
# Epoch [3/5], Loss: 1.9469
# Epoch [4/5], Loss: 1.9603
# Epoch [5/5], Loss: 1.9477
# Accuracy: 18.24%
#
# === Probando Configuración 14/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 1.9787
# Epoch [2/10], Loss: 2.0405
# Epoch [3/10], Loss: 2.0334
# Epoch [4/10], Loss: 2.0142
# Epoch [5/10], Loss: 2.0298
# Epoch [6/10], Loss: 1.9966
# Epoch [7/10], Loss: 2.0139
# Epoch [8/10], Loss: 2.0896
# Epoch [9/10], Loss: 2.0110
# Epoch [10/10], Loss: 2.0357
# Accuracy: 18.75%
#
# === Probando Configuración 15/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.9002
# Epoch [2/5], Loss: 0.7497
# Epoch [3/5], Loss: 0.6958
# Epoch [4/5], Loss: 0.7415
# Epoch [5/5], Loss: 0.6839
# Accuracy: 74.42%
#
# === Probando Configuración 16/72 ===
# Capas: [128, 64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.8479
# Epoch [2/10], Loss: 0.7100
# Epoch [3/10], Loss: 0.7020
# Epoch [4/10], Loss: 0.7337
# Epoch [5/10], Loss: 0.7170
# Epoch [6/10], Loss: 0.7702
# Epoch [7/10], Loss: 0.7854
# Epoch [8/10], Loss: 0.7983
# Epoch [9/10], Loss: 0.8232
# Epoch [10/10], Loss: 0.7475
# Accuracy: 71.40%
#
# === Probando Configuración 17/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.5195
# Epoch [2/5], Loss: 0.1891
# Epoch [3/5], Loss: 0.1355
# Epoch [4/5], Loss: 0.1089
# Epoch [5/5], Loss: 0.0949
# Accuracy: 96.50%
#
# === Probando Configuración 18/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.5179
# Epoch [2/10], Loss: 0.1864
# Epoch [3/10], Loss: 0.1353
# Epoch [4/10], Loss: 0.1103
# Epoch [5/10], Loss: 0.0945
# Epoch [6/10], Loss: 0.0831
# Epoch [7/10], Loss: 0.0763
# Epoch [8/10], Loss: 0.0699
# Epoch [9/10], Loss: 0.0645
# Epoch [10/10], Loss: 0.0602
# Accuracy: 97.23%
#
# === Probando Configuración 19/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.6404
# Epoch [2/5], Loss: 0.2133
# Epoch [3/5], Loss: 0.1507
# Epoch [4/5], Loss: 0.1161
# Epoch [5/5], Loss: 0.0955
# Accuracy: 96.68%
#
# === Probando Configuración 20/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.6533
# Epoch [2/10], Loss: 0.2226
# Epoch [3/10], Loss: 0.1579
# Epoch [4/10], Loss: 0.1241
# Epoch [5/10], Loss: 0.1045
# Epoch [6/10], Loss: 0.0883
# Epoch [7/10], Loss: 0.0773
# Epoch [8/10], Loss: 0.0660
# Epoch [9/10], Loss: 0.0596
# Epoch [10/10], Loss: 0.0534
# Accuracy: 97.06%
#
# === Probando Configuración 21/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.6367
# Epoch [2/5], Loss: 0.4543
# Epoch [3/5], Loss: 0.4413
# Epoch [4/5], Loss: 0.4150
# Epoch [5/5], Loss: 0.4090
# Accuracy: 88.47%
#
# === Probando Configuración 22/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.6749
# Epoch [2/10], Loss: 0.4875
# Epoch [3/10], Loss: 0.4609
# Epoch [4/10], Loss: 0.4356
# Epoch [5/10], Loss: 0.4275
# Epoch [6/10], Loss: 0.4127
# Epoch [7/10], Loss: 0.4254
# Epoch [8/10], Loss: 0.3947
# Epoch [9/10], Loss: 0.4017
# Epoch [10/10], Loss: 0.3735
# Accuracy: 88.76%
#
# === Probando Configuración 23/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.6307
# Epoch [2/5], Loss: 0.4037
# Epoch [3/5], Loss: 0.3663
# Epoch [4/5], Loss: 0.3497
# Epoch [5/5], Loss: 0.3396
# Accuracy: 90.06%
#
# === Probando Configuración 24/72 ===
# Capas: [128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.6891
# Epoch [2/10], Loss: 0.4218
# Epoch [3/10], Loss: 0.3798
# Epoch [4/10], Loss: 0.3632
# Epoch [5/10], Loss: 0.3432
# Epoch [6/10], Loss: 0.3336
# Epoch [7/10], Loss: 0.3391
# Epoch [8/10], Loss: 0.3252
# Epoch [9/10], Loss: 0.3234
# Epoch [10/10], Loss: 0.3194
# Accuracy: 91.78%
#
# === Probando Configuración 25/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3425
# Epoch [2/5], Loss: 0.1570
# Epoch [3/5], Loss: 0.1207
# Epoch [4/5], Loss: 0.1003
# Epoch [5/5], Loss: 0.0837
# Accuracy: 96.62%
#
# === Probando Configuración 26/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3324
# Epoch [2/10], Loss: 0.1543
# Epoch [3/10], Loss: 0.1183
# Epoch [4/10], Loss: 0.0983
# Epoch [5/10], Loss: 0.0865
# Epoch [6/10], Loss: 0.0751
# Epoch [7/10], Loss: 0.0674
# Epoch [8/10], Loss: 0.0634
# Epoch [9/10], Loss: 0.0564
# Epoch [10/10], Loss: 0.0507
# Accuracy: 97.00%
#
# === Probando Configuración 27/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3896
# Epoch [2/5], Loss: 0.1644
# Epoch [3/5], Loss: 0.1230
# Epoch [4/5], Loss: 0.0994
# Epoch [5/5], Loss: 0.0807
# Accuracy: 96.15%
#
# === Probando Configuración 28/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3733
# Epoch [2/10], Loss: 0.1657
# Epoch [3/10], Loss: 0.1179
# Epoch [4/10], Loss: 0.0944
# Epoch [5/10], Loss: 0.0824
# Epoch [6/10], Loss: 0.0707
# Epoch [7/10], Loss: 0.0625
# Epoch [8/10], Loss: 0.0586
# Epoch [9/10], Loss: 0.0509
# Epoch [10/10], Loss: 0.0471
# Accuracy: 97.11%
#
# === Probando Configuración 29/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.4679
# Epoch [2/5], Loss: 0.3241
# Epoch [3/5], Loss: 0.3140
# Epoch [4/5], Loss: 0.2866
# Epoch [5/5], Loss: 0.2878
# Accuracy: 90.52%
#
# === Probando Configuración 30/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.4559
# Epoch [2/10], Loss: 0.3131
# Epoch [3/10], Loss: 0.2861
# Epoch [4/10], Loss: 0.2752
# Epoch [5/10], Loss: 0.2580
# Epoch [6/10], Loss: 0.2553
# Epoch [7/10], Loss: 0.2586
# Epoch [8/10], Loss: 0.2532
# Epoch [9/10], Loss: 0.2353
# Epoch [10/10], Loss: 0.2580
# Accuracy: 93.93%
#
# === Probando Configuración 31/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.4262
# Epoch [2/5], Loss: 0.2537
# Epoch [3/5], Loss: 0.2383
# Epoch [4/5], Loss: 0.2226
# Epoch [5/5], Loss: 0.2111
# Accuracy: 94.24%
#
# === Probando Configuración 32/72 ===
# Capas: [256, 128, 64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.4341
# Epoch [2/10], Loss: 0.2634
# Epoch [3/10], Loss: 0.2422
# Epoch [4/10], Loss: 0.2269
# Epoch [5/10], Loss: 0.2187
# Epoch [6/10], Loss: 0.2139
# Epoch [7/10], Loss: 0.2035
# Epoch [8/10], Loss: 0.1904
# Epoch [9/10], Loss: 0.1940
# Epoch [10/10], Loss: 0.1800
# Accuracy: 94.71%
#
# === Probando Configuración 33/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3327
# Epoch [2/5], Loss: 0.2025
# Epoch [3/5], Loss: 0.1725
# Epoch [4/5], Loss: 0.1586
# Epoch [5/5], Loss: 0.1486
# Accuracy: 95.14%
#
# === Probando Configuración 34/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3350
# Epoch [2/10], Loss: 0.1972
# Epoch [3/10], Loss: 0.1681
# Epoch [4/10], Loss: 0.1513
# Epoch [5/10], Loss: 0.1504
# Epoch [6/10], Loss: 0.1428
# Epoch [7/10], Loss: 0.1412
# Epoch [8/10], Loss: 0.1395
# Epoch [9/10], Loss: 0.1341
# Epoch [10/10], Loss: 0.1288
# Accuracy: 95.24%
#
# === Probando Configuración 35/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3301
# Epoch [2/5], Loss: 0.1645
# Epoch [3/5], Loss: 0.1382
# Epoch [4/5], Loss: 0.1196
# Epoch [5/5], Loss: 0.1089
# Accuracy: 95.90%
#
# === Probando Configuración 36/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3308
# Epoch [2/10], Loss: 0.1589
# Epoch [3/10], Loss: 0.1283
# Epoch [4/10], Loss: 0.1157
# Epoch [5/10], Loss: 0.1098
# Epoch [6/10], Loss: 0.0994
# Epoch [7/10], Loss: 0.0988
# Epoch [8/10], Loss: 0.0863
# Epoch [9/10], Loss: 0.0848
# Epoch [10/10], Loss: 0.0849
# Accuracy: 96.96%
#
# === Probando Configuración 37/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 2.2876
# Epoch [2/5], Loss: 2.3732
# Epoch [3/5], Loss: 2.3730
# Epoch [4/5], Loss: 2.3735
# Epoch [5/5], Loss: 2.3746
# Accuracy: 10.32%
#
# === Probando Configuración 38/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 2.3742
# Epoch [2/10], Loss: 2.3730
# Epoch [3/10], Loss: 2.3741
# Epoch [4/10], Loss: 2.3741
# Epoch [5/10], Loss: 2.3766
# Epoch [6/10], Loss: 2.3763
# Epoch [7/10], Loss: 2.3766
# Epoch [8/10], Loss: 2.3737
# Epoch [9/10], Loss: 2.3759
# Epoch [10/10], Loss: 2.3766
# Accuracy: 10.09%
#
# === Probando Configuración 39/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 1.9190
# Epoch [2/5], Loss: 2.3245
# Epoch [3/5], Loss: 2.3530
# Epoch [4/5], Loss: 2.3463
# Epoch [5/5], Loss: 2.3524
# Accuracy: 9.74%
#
# === Probando Configuración 40/72 ===
# Capas: [256, 128, 64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 1.8186
# Epoch [2/10], Loss: 2.3524
# Epoch [3/10], Loss: 2.3516
# Epoch [4/10], Loss: 2.3508
# Epoch [5/10], Loss: 2.3477
# Epoch [6/10], Loss: 2.3514
# Epoch [7/10], Loss: 2.3516
# Epoch [8/10], Loss: 2.3519
# Epoch [9/10], Loss: 2.3501
# Epoch [10/10], Loss: 2.3506
# Accuracy: 11.35%
#
# === Probando Configuración 41/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.5513
# Epoch [2/5], Loss: 0.1779
# Epoch [3/5], Loss: 0.1328
# Epoch [4/5], Loss: 0.1138
# Epoch [5/5], Loss: 0.0972
# Accuracy: 96.88%
#
# === Probando Configuración 42/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.5638
# Epoch [2/10], Loss: 0.1813
# Epoch [3/10], Loss: 0.1390
# Epoch [4/10], Loss: 0.1172
# Epoch [5/10], Loss: 0.1012
# Epoch [6/10], Loss: 0.0904
# Epoch [7/10], Loss: 0.0845
# Epoch [8/10], Loss: 0.0811
# Epoch [9/10], Loss: 0.0741
# Epoch [10/10], Loss: 0.0664
# Accuracy: 96.26%
#
# === Probando Configuración 43/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.7486
# Epoch [2/5], Loss: 0.2081
# Epoch [3/5], Loss: 0.1428
# Epoch [4/5], Loss: 0.1109
# Epoch [5/5], Loss: 0.0919
# Accuracy: 96.96%
#
# === Probando Configuración 44/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.7175
# Epoch [2/10], Loss: 0.2008
# Epoch [3/10], Loss: 0.1379
# Epoch [4/10], Loss: 0.1079
# Epoch [5/10], Loss: 0.0930
# Epoch [6/10], Loss: 0.0787
# Epoch [7/10], Loss: 0.0704
# Epoch [8/10], Loss: 0.0628
# Epoch [9/10], Loss: 0.0570
# Epoch [10/10], Loss: 0.0528
# Accuracy: 97.34%
#
# === Probando Configuración 45/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 1.2976
# Epoch [2/5], Loss: 0.8797
# Epoch [3/5], Loss: 0.7623
# Epoch [4/5], Loss: 0.7354
# Epoch [5/5], Loss: 0.7198
# Accuracy: 80.67%
#
# === Probando Configuración 46/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.9031
# Epoch [2/10], Loss: 0.5784
# Epoch [3/10], Loss: 0.5337
# Epoch [4/10], Loss: 0.5073
# Epoch [5/10], Loss: 0.5059
# Epoch [6/10], Loss: 0.5010
# Epoch [7/10], Loss: 0.4877
# Epoch [8/10], Loss: 0.4767
# Epoch [9/10], Loss: 0.4839
# Epoch [10/10], Loss: 0.4768
# Accuracy: 84.30%
#
# === Probando Configuración 47/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.8937
# Epoch [2/5], Loss: 0.4934
# Epoch [3/5], Loss: 0.4382
# Epoch [4/5], Loss: 0.4370
# Epoch [5/5], Loss: 0.4072
# Accuracy: 88.08%
#
# === Probando Configuración 48/72 ===
# Capas: [256, 128, 64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.7503
# Epoch [2/10], Loss: 0.4662
# Epoch [3/10], Loss: 0.4097
# Epoch [4/10], Loss: 0.3910
# Epoch [5/10], Loss: 0.3710
# Epoch [6/10], Loss: 0.3747
# Epoch [7/10], Loss: 0.3706
# Epoch [8/10], Loss: 0.3545
# Epoch [9/10], Loss: 0.3425
# Epoch [10/10], Loss: 0.3504
# Accuracy: 87.81%
#
# === Probando Configuración 49/72 ===
# Capas: [64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3853
# Epoch [2/5], Loss: 0.2158
# Epoch [3/5], Loss: 0.1677
# Epoch [4/5], Loss: 0.1395
# Epoch [5/5], Loss: 0.1239
# Accuracy: 96.60%
#
# === Probando Configuración 50/72 ===
# Capas: [64] | Activación: relu | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3748
# Epoch [2/10], Loss: 0.2107
# Epoch [3/10], Loss: 0.1616
# Epoch [4/10], Loss: 0.1359
# Epoch [5/10], Loss: 0.1201
# Epoch [6/10], Loss: 0.1084
# Epoch [7/10], Loss: 0.0997
# Epoch [8/10], Loss: 0.0937
# Epoch [9/10], Loss: 0.0857
# Epoch [10/10], Loss: 0.0815
# Accuracy: 96.39%
#
# === Probando Configuración 51/72 ===
# Capas: [64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.4304
# Epoch [2/5], Loss: 0.2493
# Epoch [3/5], Loss: 0.1878
# Epoch [4/5], Loss: 0.1505
# Epoch [5/5], Loss: 0.1301
# Accuracy: 95.95%
#
# === Probando Configuración 52/72 ===
# Capas: [64] | Activación: relu | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.4275
# Epoch [2/10], Loss: 0.2425
# Epoch [3/10], Loss: 0.1830
# Epoch [4/10], Loss: 0.1476
# Epoch [5/10], Loss: 0.1277
# Epoch [6/10], Loss: 0.1152
# Epoch [7/10], Loss: 0.1031
# Epoch [8/10], Loss: 0.0939
# Epoch [9/10], Loss: 0.0864
# Epoch [10/10], Loss: 0.0816
# Accuracy: 96.56%
#
# === Probando Configuración 53/72 ===
# Capas: [64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.4233
# Epoch [2/5], Loss: 0.3553
# Epoch [3/5], Loss: 0.3300
# Epoch [4/5], Loss: 0.3245
# Epoch [5/5], Loss: 0.3132
# Accuracy: 91.14%
#
# === Probando Configuración 54/72 ===
# Capas: [64] | Activación: relu | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.4214
# Epoch [2/10], Loss: 0.3467
# Epoch [3/10], Loss: 0.3313
# Epoch [4/10], Loss: 0.3164
# Epoch [5/10], Loss: 0.3121
# Epoch [6/10], Loss: 0.3038
# Epoch [7/10], Loss: 0.2899
# Epoch [8/10], Loss: 0.2874
# Epoch [9/10], Loss: 0.2888
# Epoch [10/10], Loss: 0.2841
# Accuracy: 93.12%
#
# === Probando Configuración 55/72 ===
# Capas: [64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.4610
# Epoch [2/5], Loss: 0.3422
# Epoch [3/5], Loss: 0.3291
# Epoch [4/5], Loss: 0.3188
# Epoch [5/5], Loss: 0.3078
# Accuracy: 92.18%
#
# === Probando Configuración 56/72 ===
# Capas: [64] | Activación: relu | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.4274
# Epoch [2/10], Loss: 0.3001
# Epoch [3/10], Loss: 0.2806
# Epoch [4/10], Loss: 0.2665
# Epoch [5/10], Loss: 0.2712
# Epoch [6/10], Loss: 0.2510
# Epoch [7/10], Loss: 0.2559
# Epoch [8/10], Loss: 0.2448
# Epoch [9/10], Loss: 0.2384
# Epoch [10/10], Loss: 0.2438
# Accuracy: 92.96%
#
# === Probando Configuración 57/72 ===
# Capas: [64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.3553
# Epoch [2/5], Loss: 0.2044
# Epoch [3/5], Loss: 0.1662
# Epoch [4/5], Loss: 0.1468
# Epoch [5/5], Loss: 0.1362
# Accuracy: 95.81%
#
# === Probando Configuración 58/72 ===
# Capas: [64] | Activación: tanh | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.3512
# Epoch [2/10], Loss: 0.2007
# Epoch [3/10], Loss: 0.1664
# Epoch [4/10], Loss: 0.1461
# Epoch [5/10], Loss: 0.1326
# Epoch [6/10], Loss: 0.1233
# Epoch [7/10], Loss: 0.1214
# Epoch [8/10], Loss: 0.1163
# Epoch [9/10], Loss: 0.1165
# Epoch [10/10], Loss: 0.1113
# Accuracy: 95.85%
#
# === Probando Configuración 59/72 ===
# Capas: [64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.3907
# Epoch [2/5], Loss: 0.2056
# Epoch [3/5], Loss: 0.1646
# Epoch [4/5], Loss: 0.1390
# Epoch [5/5], Loss: 0.1255
# Accuracy: 95.61%
#
# === Probando Configuración 60/72 ===
# Capas: [64] | Activación: tanh | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.3908
# Epoch [2/10], Loss: 0.2068
# Epoch [3/10], Loss: 0.1635
# Epoch [4/10], Loss: 0.1411
# Epoch [5/10], Loss: 0.1270
# Epoch [6/10], Loss: 0.1127
# Epoch [7/10], Loss: 0.1041
# Epoch [8/10], Loss: 0.0985
# Epoch [9/10], Loss: 0.0897
# Epoch [10/10], Loss: 0.0848
# Accuracy: 96.43%
#
# === Probando Configuración 61/72 ===
# Capas: [64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 1.7503
# Epoch [2/5], Loss: 1.5645
# Epoch [3/5], Loss: 1.5359
# Epoch [4/5], Loss: 1.5302
# Epoch [5/5], Loss: 1.5120
# Accuracy: 37.62%
#
# === Probando Configuración 62/72 ===
# Capas: [64] | Activación: tanh | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 1.9904
# Epoch [2/10], Loss: 1.9507
# Epoch [3/10], Loss: 1.9490
# Epoch [4/10], Loss: 1.9475
# Epoch [5/10], Loss: 1.9461
# Epoch [6/10], Loss: 1.9394
# Epoch [7/10], Loss: 1.9333
# Epoch [8/10], Loss: 1.9361
# Epoch [9/10], Loss: 1.9280
# Epoch [10/10], Loss: 1.9203
# Accuracy: 18.41%
#
# === Probando Configuración 63/72 ===
# Capas: [64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.8257
# Epoch [2/5], Loss: 0.6605
# Epoch [3/5], Loss: 0.6253
# Epoch [4/5], Loss: 0.6231
# Epoch [5/5], Loss: 0.6107
# Accuracy: 85.12%
#
# === Probando Configuración 64/72 ===
# Capas: [64] | Activación: tanh | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.7524
# Epoch [2/10], Loss: 0.5754
# Epoch [3/10], Loss: 0.5587
# Epoch [4/10], Loss: 0.5670
# Epoch [5/10], Loss: 0.5395
# Epoch [6/10], Loss: 0.5355
# Epoch [7/10], Loss: 0.5482
# Epoch [8/10], Loss: 0.5262
# Epoch [9/10], Loss: 0.5112
# Epoch [10/10], Loss: 0.5096
# Accuracy: 86.21%
#
# === Probando Configuración 65/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.4672
# Epoch [2/5], Loss: 0.2241
# Epoch [3/5], Loss: 0.1786
# Epoch [4/5], Loss: 0.1491
# Epoch [5/5], Loss: 0.1309
# Accuracy: 96.18%
#
# === Probando Configuración 66/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.001 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.4719
# Epoch [2/10], Loss: 0.2248
# Epoch [3/10], Loss: 0.1754
# Epoch [4/10], Loss: 0.1492
# Epoch [5/10], Loss: 0.1283
# Epoch [6/10], Loss: 0.1153
# Epoch [7/10], Loss: 0.1053
# Epoch [8/10], Loss: 0.0961
# Epoch [9/10], Loss: 0.0888
# Epoch [10/10], Loss: 0.0847
# Accuracy: 96.75%
#
# === Probando Configuración 67/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.5711
# Epoch [2/5], Loss: 0.2612
# Epoch [3/5], Loss: 0.2062
# Epoch [4/5], Loss: 0.1749
# Epoch [5/5], Loss: 0.1515
# Accuracy: 95.52%
#
# === Probando Configuración 68/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.001 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.5648
# Epoch [2/10], Loss: 0.2569
# Epoch [3/10], Loss: 0.2049
# Epoch [4/10], Loss: 0.1717
# Epoch [5/10], Loss: 0.1502
# Epoch [6/10], Loss: 0.1339
# Epoch [7/10], Loss: 0.1200
# Epoch [8/10], Loss: 0.1097
# Epoch [9/10], Loss: 0.1008
# Epoch [10/10], Loss: 0.0932
# Accuracy: 96.75%
#
# === Probando Configuración 69/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 5
# Epoch [1/5], Loss: 0.5999
# Epoch [2/5], Loss: 0.4318
# Epoch [3/5], Loss: 0.4361
# Epoch [4/5], Loss: 0.4235
# Epoch [5/5], Loss: 0.4040
# Accuracy: 89.42%
#
# === Probando Configuración 70/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.01 | Batch: 32 | Epochs: 10
# Epoch [1/10], Loss: 0.5588
# Epoch [2/10], Loss: 0.4482
# Epoch [3/10], Loss: 0.4420
# Epoch [4/10], Loss: 0.4514
# Epoch [5/10], Loss: 0.4283
# Epoch [6/10], Loss: 0.4027
# Epoch [7/10], Loss: 0.3967
# Epoch [8/10], Loss: 0.3815
# Epoch [9/10], Loss: 0.3804
# Epoch [10/10], Loss: 0.3801
# Accuracy: 90.52%
#
# === Probando Configuración 71/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 5
# Epoch [1/5], Loss: 0.5438
# Epoch [2/5], Loss: 0.3844
# Epoch [3/5], Loss: 0.3565
# Epoch [4/5], Loss: 0.3420
# Epoch [5/5], Loss: 0.3410
# Accuracy: 90.99%
#
# === Probando Configuración 72/72 ===
# Capas: [64] | Activación: sigmoid | LR: 0.01 | Batch: 64 | Epochs: 10
# Epoch [1/10], Loss: 0.5820
# Epoch [2/10], Loss: 0.3913
# Epoch [3/10], Loss: 0.3653
# Epoch [4/10], Loss: 0.3448
# Epoch [5/10], Loss: 0.3366
# Epoch [6/10], Loss: 0.3347
# Epoch [7/10], Loss: 0.3258
# Epoch [8/10], Loss: 0.3208
# Epoch [9/10], Loss: 0.3218
# Epoch [10/10], Loss: 0.3124
# Accuracy: 91.33%

# %%
#Tabla final y ranking
df_grid = pd.DataFrame(grid_results)
df_grid = df_grid.sort_values(by="Accuracy", ascending=False).reset_index(drop=True)
print("\nRanking de todas las combinaciones probadas:")
print(df_grid.head(10))  # Muestra las 10 mejores
# Out:
# Ranking de todas las combinaciones probadas:
#     Capas Ocultas Activación  Learning Rate  Batch Size  Epochs  Accuracy
# 0  [256, 128, 64]    sigmoid          0.001          64      10     97.34
# 1       [128, 64]    sigmoid          0.001          32      10     97.23
# 2  [256, 128, 64]       relu          0.001          64      10     97.11
# 3       [128, 64]       relu          0.001          32      10     97.10
# 4       [128, 64]       relu          0.001          64       5     97.10
# 5       [128, 64]       relu          0.001          64      10     97.07
# 6       [128, 64]    sigmoid          0.001          64      10     97.06
# 7  [256, 128, 64]       relu          0.001          32      10     97.00
# 8  [256, 128, 64]    sigmoid          0.001          64       5     96.96
# 9  [256, 128, 64]       tanh          0.001          64      10     96.96
